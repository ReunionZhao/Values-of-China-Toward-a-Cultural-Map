# %%
from openai import OpenAI
# 设置 API 密钥和组织
api_key = "sk-WO49kazJ9a1PDGbE2lPRhJ9vDG8hak5_mbD60YhIB8T3BlbkFJHbhSLNYAPwzhLHjS72qabHWqGwtBmAvgRpRwN_iYMA"
client = OpenAI(api_key=api_key)

# 设置组织信息
client.organization = "org-34qJHjOz4UGZYVqv2zlohVMe"

# %%
import os
import json
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# 分析故事内容的函数
def analyze_story_content(text_segment):
    prompt = (
        f"你是一位精通中国民间故事研究的研究员。"
        f"请分析以下故事内容，并准确回答以下问题。"
        f"回答时请直接根据故事内容进行判断，不要发散联想或做出推测。"
        f"回答格式为 1 或 0，其中 1 表示提及，0 表示未提及。\n\n"
        f"1. 故事内容中是否提及畜牧业，例如放牧牛羊？\n"
        f"2. 故事内容中是否提及棉花，例如棉花的种植或使用？\n"
        f"3. 故事内容中是否提及小麦，例如小麦的种植或使用？\n"
        f"4. 故事内容中是否提及渔业或水产养殖，例如捕鱼、养鱼或其他水产活动？\n\n"
        f"请按照以下 JSON 格式返回结果：\n"
        f'{{"畜牧业": 0 or 1, "棉花": 0 or 1, "小麦": 0 or 1, "渔业": 0 or 1}}\n\n'
        f"以下是故事内容：\n{text_segment}"
    )
    
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=100,
            temperature=0.1,
            top_p=0.9
        )
        result = response.choices[0].message.content.strip()
        
        # 尝试将结果解析为 Python 字典
        parsed_result = json.loads(result)
        return parsed_result
    except Exception as e:
        print(f"Error processing text segment: {e}")
        return {"畜牧业": 0, "棉花": 0, "小麦": 0, "渔业": 0}

# 处理单个文件并返回分析结果
def process_single_file(file_path):
    file_name = os.path.basename(file_path)

    # 读取文件内容
    with open(file_path, 'r', encoding='utf-8') as file:
        text_content = file.read()

    # 分析故事内容
    analysis_result = analyze_story_content(text_content)

    # 组织数据行
    row = {
        "文件名称": file_name,
        "文本内容": text_content,
        "畜牧业": analysis_result.get("畜牧业", 0),
        "棉花": analysis_result.get("棉花", 0),
        "小麦": analysis_result.get("小麦", 0),
        "渔业": analysis_result.get("渔业", 0),
    }
    return row

# 处理文件夹中的所有 .txt 文件并分批保存
def process_all_txt_files(input_folder, output_excel_folder):
    # 创建结果存储文件夹
    if not os.path.exists(output_excel_folder):
        os.makedirs(output_excel_folder)
    
    # 获取所有的txt文件
    all_txt_files = []
    for root, _, files in os.walk(input_folder):
        for file_name in files:
            if file_name.endswith('.txt'):
                all_txt_files.append(os.path.join(root, file_name))

    # 使用ThreadPoolExecutor并行处理文件，增加线程数来提高并行度
    data = []
    file_count = 0
    output_batch_count = 1  # 用于命名输出文件

    with tqdm(total=len(all_txt_files), desc="Processing Files") as pbar:
        # 增加最大线程数（如：20）
        with ThreadPoolExecutor(max_workers=40) as executor:
            future_to_file = {executor.submit(process_single_file, file_path): file_path for file_path in all_txt_files}
            
            for future in as_completed(future_to_file):
                result = future.result()
                data.append(result)
                file_count += 1
                
                # 每1000条数据保存一个批次的xlsx文件
                if file_count >= 1000:
                    output_file = os.path.join(output_excel_folder, f"batch_{output_batch_count}.csv")  # 使用CSV格式加快保存速度
                    df = pd.DataFrame(data)
                    df.to_csv(output_file, index=False, encoding='utf-8')  # 使用CSV格式
                    print(f"批次 {output_batch_count} 保存到 {output_file}")
                    
                    # 重置数据列表并更新批次编号
                    data = []
                    file_count = 0
                    output_batch_count += 1
                
                # 更新进度条
                pbar.update(1)

    # 最后保存剩余的数据
    if data:
        output_file = os.path.join(output_excel_folder, f"batch_{output_batch_count}.csv")  # 使用CSV格式
        df = pd.DataFrame(data)
        df.to_csv(output_file, index=False, encoding='utf-8')  # 使用CSV格式
        print(f"批次 {output_batch_count} 保存到 {output_file}")

    # 合并所有批次文件为一个文件
    all_batches = []
    for root, _, files in os.walk(output_excel_folder):
        for file_name in files:
            if file_name.endswith('.csv'):  # 合并CSV文件
                file_path = os.path.join(root, file_name)
                all_batches.append(pd.read_csv(file_path))

    # 合并所有数据
    combined_df = pd.concat(all_batches, ignore_index=True)

    # 最终合并后的文件命名为 '241123validation_question_analysis_results.csv'
    final_output_file = os.path.join(output_excel_folder, '241123validation_question_analysis_results.csv')
    combined_df.to_csv(final_output_file, index=False, encoding='utf-8')  # 使用CSV格式
    print(f"所有结果已合并并保存到 {final_output_file}")

# 指定输入文件夹和输出文件夹路径
input_folder = "/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/data/raw_data_tales"
output_excel_folder = "/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results"

# 运行主函数
process_all_txt_files(input_folder, output_excel_folder)
# Out:
# Processing Files:   6%|▌         | 1003/17324 [00:31<10:04, 27.00it/s]
# 批次 1 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_1.csv
# Processing Files:   7%|▋         | 1193/17324 [00:38<09:48, 27.42it/s]
# Error processing text segment: Expecting value: line 1 column 1 (char 0)
# Processing Files:  12%|█▏        | 2008/17324 [01:05<08:20, 30.59it/s]
# 批次 2 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_2.csv
# Processing Files:  17%|█▋        | 3007/17324 [01:45<08:04, 29.54it/s]
# 批次 3 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_3.csv
# Processing Files:  23%|██▎       | 4004/17324 [02:19<06:59, 31.76it/s]
# 批次 4 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_4.csv
# Processing Files:  29%|██▉       | 5005/17324 [02:51<07:09, 28.71it/s]
# 批次 5 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_5.csv
# Processing Files:  35%|███▍      | 6004/17324 [03:30<11:43, 16.09it/s]
# 批次 6 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_6.csv
# Processing Files:  40%|████      | 7005/17324 [04:04<05:12, 33.03it/s]
# 批次 7 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_7.csv
# Processing Files:  46%|████▌     | 8004/17324 [04:39<08:09, 19.02it/s]
# 批次 8 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_8.csv
# Processing Files:  52%|█████▏    | 9008/17324 [05:14<03:49, 36.24it/s]
# 批次 9 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_9.csv
# Processing Files:  58%|█████▊    | 10004/17324 [05:45<03:25, 35.68it/s]
# 批次 10 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_10.csv
# Processing Files:  64%|██████▎   | 11008/17324 [06:23<03:06, 33.92it/s]
# 批次 11 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_11.csv
# Processing Files:  69%|██████▉   | 11999/17324 [07:00<02:18, 38.56it/s]
# 批次 12 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_12.csv
# Processing Files:  75%|███████▌  | 13004/17324 [07:32<02:25, 29.66it/s]
# 批次 13 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_13.csv
# Processing Files:  78%|███████▊  | 13441/17324 [07:46<01:42, 37.77it/s]
# Error processing text segment: Expecting value: line 1 column 1 (char 0)
# Processing Files:  81%|████████  | 14004/17324 [08:04<01:26, 38.33it/s]
# 批次 14 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_14.csv
# Processing Files:  87%|████████▋ | 15004/17324 [08:41<01:23, 27.92it/s]
# 批次 15 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_15.csv
# Processing Files:  92%|█████████▏| 16010/17324 [09:13<00:34, 38.38it/s]
# 批次 16 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_16.csv
# Processing Files:  98%|█████████▊| 17005/17324 [09:44<00:09, 33.32it/s]
# 批次 17 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_17.csv
# Processing Files: 100%|██████████| 17324/17324 [10:00<00:00, 28.84it/s]
# 批次 18 保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/batch_18.csv
# 所有结果已合并并保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/241123validation_question_analysis_results.csv

# %%
file_path = "/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123validation_question_analysis_results/241123validation_question_analysis_results.csv"
df = pd.read_csv(file_path)
df['文件名称'] = df['文件名称'].str.replace('.txt', '', regex=False)
df.shape[0]
# Out:
# 17324

# %% [markdown]
# 剔除 吉林旧 和 少数民族
# 4）	暂时不要包括少数民族--他们的故事通常是比较不同的，我们之后需要单独研究他们
# "E:\坚果云\润平\from MX\少数民族\Merged_Ethnicity_Data_with_English_Names_Xue.csv"
# 相关少数民族的故事，和对应的ethnic group（in english)。目前阶段只需要把这些故事剔除

# %%
import os
import pandas as pd

# 读取文件夹内所有txt文件的名称（不含.txt）
def get_txt_filenames(folder_path):
    txt_files = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            # 去掉文件扩展名（.txt）
            txt_files.append(os.path.splitext(file_name)[0])
    return txt_files

# 读取CSV文件中的"Name"列
def get_names_from_csv(csv_path):
    df = pd.read_csv(csv_path)
    # 假设CSV中有"Name"列
    return df['name'].tolist()

# 设置路径
folder_path = '/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/data/raw_data_tales/吉林596'
csv_path = '/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/data/Merged_Ethnicity_Data_with_English_Names_Xue.csv'

# 获取txt文件名称
txt_filenames = get_txt_filenames(folder_path)

# 获取CSV文件中的名称
csv_names = get_names_from_csv(csv_path)

# 合并两个列表
combined_list = txt_filenames + csv_names
combined_list
# Out:
# ['02084__062严羽暑天着羊裘',
#  '02081__059李纲巧阻皇帝过沙县',
#  '02127__108王绍兰判斗案',
#  '02246__228资国寺',
#  '02399__386-老鼠借牙',
#  '02336__321明姜的传说',
#  '02128__109谢瑁樵三难学台',
#  '02284__266抓“苏维埃',
#  '02028__003,皇天爷和皇天姆造人',
#  '02310__294还瑰草',
#  '02571__564包国生逗贪吃',
#  '02100__079-万人锅',
#  '02518__510义盗宋沼',
#  '02560__553-寡妇改嫁',
#  '02502__493考女婿',
#  '02329__313龙眼果和桂圆干',
#  '02535__527县太爷选贤人',
#  '02113__095大力士吴仔恩',
#  '02121__102叫化子喝老爷',
#  '02151__132放下屠刀立地成佛',
#  '02578__571赵六滩斗知县',
#  '02479__469巧妇智斗“鸭肉香',
#  '02506__497-两瓮银',
#  '02250__232万木林的来历',
#  '02066__043风吹松子满山生',
#  '02082__060王璞作活画',
#  '02297__281五步蛇',
#  '02172__153杉竹和合',
#  '02279__261-#被',
#  '02132__113智除奸细',
#  '02348__333“佛跳墙”的传说',
#  '02242__224雪峰寺的传说',
#  '02281__263陈毅拜师',
#  '02557__549冬夜擒贼',
#  '02042__019#罗解梦',
#  '02389__376红布盖头的由来',
#  '02496__487“铁公鸡吃鸡',
#  '02237__219通仙桥',
#  '02492__483长年智斗财主',
#  '02075__053葱补丹田麦补脾',
#  '02527__519百忍堂',
#  '02228__210望云楼',
#  '02201__183-出钱石',
#  '02358__344二月二的由来',
#  '02280__262草鞋船',
#  '02598__591学懒',
#  '02212__194银池岗',
#  '02516__508三家福',
#  '02190__171美人山望台湾',
#  '02463__453郭魁羽娶狐狸精',
#  '02590__583今旦是灶公灶婆做生0',
#  '02194__175天湖山的传说',
#  '02218__200合竹溪',
#  '02401__388,鳌虾跳龙门',
#  '02296__280-it为啥冬眠',
#  '02198__179,仙人请客',
#  '02507__498金哥银弟',
#  '02436__424蛇郎君',
#  '02225__207天下第一楼',
#  '02307__291灵芝仙子',
#  '02117__099李相爷结拜贩猪客',
#  '02221__203榕树和榕城的传说',
#  '02334__319四季橄榄',
#  '02556__548智救弱女',
#  '02074__052-朱熹写“桃',
#  '02550__542陈振赐胜官司',
#  '02392__379乾隆君闹洞房',
#  '02453__442鬼报恩',
#  '02268__250寡妇塔',
#  '02143__124-张果老斗妖',
#  '02534__526潘涂翻旧案',
#  '02331__316兰竹荔枝',
#  '02577__570,潘统斗刁官',
#  '02459__448“猪仔”换“猪公”',
#  '02220__202,河田烧水塘',
#  '02226__208云峰楼',
#  '02096__074,思儿亭',
#  '02211__193-白云山银坑洞',
#  '02371__358畲族女人衫里有两个皇帝印',
#  '02235__217洛阳桥的传说',
#  '02488__479三女婿巧对酒令',
#  '02355__341,过年风俗的来历',
#  '02326__310漳州片仔白',
#  '02027__002盘古女蜗成亲',
#  '02283__265王占春巧摆西瓜阵',
#  '02339__324不孝笋的传说',
#  '02600__593徒弟的“贺樟”',
#  '02540__532设宴出谜题',
#  '02324__308三蛇酒',
#  '02298__282鸳鸯的传说',
#  '02312__296-水仙茶',
#  '02304__288鹰为什么会在空中盘旋',
#  '02134__115林则徐劝友戒烟',
#  '02158__139镇两妖',
#  '02090__068马乐赶考',
#  '02567__560包国生斗山主',
#  '02468__458雷打螟蚣石',
#  '02561__554巧计定是非',
#  '02342__327鳄鱼屿与文昌鱼',
#  '02029__004油火烧天下',
#  '02553__545替姑母争气',
#  '02544__536邱蒙放大炮',
#  '02202__184-剥皮石',
#  '02404__391飞去。',
#  '02421__408告阴状',
#  '02244__226清水岩',
#  '02406__392仙姑救婢女',
#  '02384__371不要做寿',
#  '02195__176太子山',
#  '02278__260红军不骗百姓',
#  '02139__120鬼谷子算命',
#  '02061__038半仙罗隐',
#  '02465__455孤女斗蛇精',
#  '02332__317绿砂荔枝',
#  '02111__093-国姓鞋',
#  '02318__302“白鸡冠”茶',
#  '02133__114林皿徐巧布尿壷阵',
#  '02351__337田黄石的传说',
#  '02200__182雁石的传说',
#  '02449__438-天竹岩仙人厝',
#  '02109__091崇祯测字',
#  '02170__151马文才与梁祝双状元',
#  '02136__117唐世济审石头',
#  '02532__524算命先生的故事',
#  '02541__533郑堂做长工',
#  '02551__543教训知县',
#  '02414__400四方鸭蛋',
#  '02034__010农神和衣神',
#  '02089__067-—日君马乐',
#  '02364__351“团圆节”的来历',
#  '02178__159秦始皇遮日',
#  '02054__031,戏状元雷海青',
#  '02513__505一个老人的故事',
#  '02359__345风吹头巾雨渥花粉',
#  '02591__584我妻逼我来',
#  '02411__397正善与无心',
#  '02396__383柜台前摆条凳的传说',
#  '02338__323金山玉笋',
#  '02186__167大王与玉女',
#  '02300__284-布谷鸟',
#  '02603__596贺联',
#  '02103__084一日皇君董应举',
#  '02204__186镇海石的传说',
#  '02189__170涌泉寺的传说',
#  '02521__513-两块银元救了五条命',
#  '02417__404-七彩石',
#  '02514__506猪肚炖莲籽吃多慢慢死',
#  '02398__385老虎吃獐',
#  '02458__447鬼太守',
#  '02255__237万金油大王胡文虎',
#  '02308__292冬笋',
#  '02270__252当境王爷',
#  '02260__242月里寻夫',
#  '02240__222串心亭',
#  '02299__283-哥哥鸟',
#  '02539__531郑堂接对联娶了好媳妇',
#  '02327__311水仙花',
#  '02604__■346清明插柳的传说',
#  '02461__449水鬼升城隍',
#  '02156__137妈祖降怪',
#  '02363__350-分龙芍',
#  '02145__126±地庙为什么没土地婆',
#  '02376__363吃“红肉过年的传说',
#  '02470__460-帮工和小姐',
#  '02059__036丞相祝寿',
#  '02605__中国民间故事集成',
#  '02448__437三千八百坎，坎坎出黄金',
#  '02039__015孔子无奈拗事馆',
#  '02517__509路遥知马力',
#  '02053__030梅妃的传说',
#  '02584__577神童见皇帝',
#  '02428__416田螺娘子',
#  '02180__161白蛇和青蛇',
#  '02165__146圣泉救疫',
#  '02276__258-铜尿壶',
#  '02152__133敲木鱼',
#  '02263__245-金顶针',
#  '02064__041做豆腐会发家',
#  '02595__588县官送礼',
#  '02274__256-刚果的泉州荔枝',
#  '02288__271海底鸳鸯',
#  '02588__581线路来得紧',
#  '02030__005天火',
#  '02057__034鸭娘皇后',
#  '02320__304“铁观音”的传说',
#  '02500__491智灭鸦片苗',
#  '02354__340祭灶的传说',
#  '02191__172,冠M山的传说',
#  '02219__201西波浪潭',
#  '02293__276考十二生肖',
#  '02564__557巧妙的地契',
#  '02264__246番客说怕',
#  '02367__354歌舞的来历',
#  '02277__259,先薯亭',
#  '02309__293-何首乌',
#  '02177__158秦始皇的传说',
#  '02038__014畲族姓氏及世居山脚的来历',
#  '02302__286鹏鸠',
#  '02387__374龙驾轿',
#  '02287__269蚂虎',
#  '02471__461“片钱姑”奇缘',
#  '02340__325建莲的传说',
#  '02442__430八哥衔耳环',
#  '02072__050郑樵与鲤娘',
#  '02217__199金溪的传说',
#  '02078__056-陈北溪画月',
#  '02126__107神鸭',
#  '02241__223绿轿亭',
#  '02543__535鸡笼做灯府台赏钱',
#  '02529__521—针救两命甘草毒死人',
#  '02586__579马虎先生',
#  '02333__318岩根枇杷',
#  '02383__37015子点乌烟的来历',
#  '02079__057李纲辩“马”',
#  '02512__504瓦片比囹好',
#  '02480__470李敢娘智破“摸喜”陋俗',
#  '02503__494药联择婿',
#  '02052__029-太白回书',
#  '02239__221天下无桥短此桥',
#  '02435__423-虎外婆',
#  '02368__355-三角戏',
#  '02388__375官轿让花轿',
#  '02523__515-系鞘奇缘',
#  '02491__482“金马驹”与“火龙衣”',
#  '02306__290牡丹茶花',
#  '02489__480闽南木门槛上盖竹板的来历',
#  '02499__490八尺岭上日日冬至',
#  '02601__594众工协力',
#  '02573__566郑大济难知县',
#  '02040__016祖师斗法',
#  '02498__489秀才卖喜联',
#  '02599__592胡医生',
#  '02505__496州官巧断逆子案',
#  '02159__140伏机救亲',
#  '02199__180五福洋',
#  '02065__042水浸万年松',
#  '02122__103+子同居',
#  '02422__409穷书生与海龙女',
#  '02349__334石狮甜铢的来历',
#  '02602__595三“宝学艺',
#  '02048__025关爷遇害成神',
#  '02106__088-替土地公说句心里话',
#  '02088__066穷秀才巧遇永乐帝',
#  '02487__478不是府里见，就是省里见',
#  '02080__058李纲种桧树',
#  '02252__234-千年不朽木',
#  '02262__244情义值千金',
#  '02415__402张赵二郎',
#  '02486__477无烦恼',
#  '02546__538邱蒙伏虎',
#  '02036__012眨刀婆',
#  '02344__329二都蜥',
#  '02425__413人心不足蛇吞相',
#  '02525__517贼仔三立功',
#  '02365__352,茶灯舞的来由',
#  '02083__061严羽钓鱼',
#  '02289__272鱼死了为什么眼睛还睁着',
#  '02346__331-±杭腊货的传说',
#  '02378__365小五荤',
#  '02526__518-满足堂',
#  '02092__070马铎吃薯榔',
#  '02370__357凤凰装束的由来',
#  '02429__417田螺姑娘',
#  '02347__332“福寿全”与“佛跳墙”',
#  '02231__213罗星塔',
#  '02026__001,盘古分开地',
#  '02444__433-金栗子和石蛋子',
#  '02434__422-十兄弟闹皇宫',
#  '02313__297木芙蓉',
#  '02205__187石头人的传说',
#  '02341__326金定鸭',
#  '02120__101乾隆皇帝到禾坪',
#  '02325__309-薪蛇酒',
#  '02035__011雷公与雷婆',
#  '02232__214水南塔的传说',
#  '02390__377洞房花烛夜为啥放鞭炮',
#  '02267__249姑嫂塔',
#  '02587__580乱吹箫',
#  '02258__240,兴学一千所',
#  '02353__339-永春漆篮的来历',
#  '02295__279山鸡三告状',
#  '02153__134保童神临水奶',
#  '02141__122吕洞宾与四大金刚',
#  '02451__440水鬼朋友',
#  '02070__047吴夺医太后',
#  '02563__556续对济穷人',
#  '02531__523笑话治病',
#  '02129__110林俊飞铜除暴',
#  '02515__507四个“恭喜”不如一个“也好”',
#  '02430__418命带十八败',
#  '02356__342大年三十烧松光火',
#  '02213__195-5龙屿',
#  '02570__563包国生斗老板',
#  '02403__390范丹寻如来',
#  '02360__347吃乌饭',
#  '02049__026张飞下战书',
#  '02419__406有缘千里来相会',
#  '02452__441-义鬼',
#  '02230__212乌塔与白塔',
#  '02098__077邓茂七放鸭母',
#  '02256__238我是“中国虎',
#  '02568__561包国生斗税官',
#  '02566__559包国生斗田主',
#  '02555__547三个铜钱完钱粮',
#  '02374__361栽禾饭桌上莫乱坐',
#  '02446__435莫神仙',
#  '02440__428-海水晒盐的来历',
#  '02418__405蓝金凤除黄甲精',
#  '02197__178幔亭宴和虹桥板',
#  '02183__164牛郎织女与“记节”习俗',
#  '02063__040稻秧洗掉泥土更会长',
#  '02420__407-聚宝盆',
#  '02457__446-张圣公斗五鬼',
#  '02291__274牛原是天廷丞相',
#  '02041__018秦始皇巡游遇“山哈',
#  '02124__105,黄慎学画',
#  '02102__083王天官跟海瑞',
#  '02445__434龙灯',
#  '02501__492母舅分牛',
#  '02455__444有胆能叫鬼挑担',
#  '02193__174大帽山与三进屿',
#  '02542__534郑堂过年',
#  '02131__112割耳示众',
#  '02060__037罗隐的传说',
#  '02215__197汀江的传说',
#  '02335__320明姜的来历',
#  '02504__495秀才“休妻度荒年',
#  '02412__398夜明珠',
#  '02319__303银针茶',
#  '02253__235积墨池',
#  '02222__204桃林村名的由来',
#  '02493__484丁二戏财主',
#  '02223__205飞钱巷',
#  '02238__220倒桥皇后',
#  '02077__055抓朱熹',
#  '02166__147雾海神灯',
#  '02574__567写诉呈',
#  '02408__394老虎抢亲',
#  '02273__255M莉仙子',
#  '02439__427石磨磨盐',
#  '02569__562包国生斗知县',
#  '02144__125韩湘子成仙',
#  '02188__169鼓山的传说',
#  '02149__130阿弥驮佛',
#  '02234__216万寿桥',
#  '02032__008月亮和太阳',
#  '02094__072林希元做女婿',
#  '02037__013-山羊与地震',
#  '02271__253七美屿',
#  '02478__468-九斤姑娘',
#  '02548__540邱蒙请半仙',
#  '02377__364红布糕羊牯酒',
#  '02251__233葫芦破腹',
#  '02596__589兄弟买鞋',
#  '02243__225呼孙岩',
#  '02167__148师泉井',
#  '02437__425俩兄弟',
#  '02520__512砍柴园中状元郎',
#  '02423__410海镜宝',
#  '02443__432罗山得银',
#  '02511__502两个父亲',
#  '02426__414宝盆',
#  '02581__574阿成哥编故事',
#  '02483__474巧姑斗才子',
#  '02583__576有蝴无肉',
#  '02265__247补伯不爱闹热',
#  '02085__063-刘伯温和朱元璋作对',
#  '02474__464陈三五娘',
#  '02424__411只可救虫，不可救人',
#  '02393__380新妇为什么要破金瓜',
#  '02394__381“好兄弟',
#  '02176__157西瓜精点倒长城',
#  '02343__328戦的传说',
#  '02208__190瓜果洞的传说',
#  '02147__128葱菜成成神',
#  '02490__481二八姑娘三岁郎',
#  '02115__097洪母斥子',
#  '02154__135妈祖出世',
#  '02050__027董奉与董奉山',
#  '02056__033黄巢断案',
#  '02175__156-孟姜女变花报夫仇',
#  '02203__185黄巢试剑石',
#  '02373__360李九我定席位',
#  '02386__373畲族新娘套穿白衣裤的传说',
#  '02071__048杨龟山教太子',
#  '02400__387凤凰和鸡牯',
#  '02045__022周瑜、鲁肃和诸葛亮行酒令',
#  '02410__396善求和恶求',
#  '02582__575-郭智巧谑县老爷',
#  '02148__129赵公财神',
#  '02285__267“算盘”叔卖菜',
#  '02580__573巧治张师爷',
#  '02044__021李寄斩蛇',
#  '02323__307沉缸酒的传说',
#  '02407__393-义虎亭',
#  '02301__285-吉祥鸟',
#  '02466__456宝镜坑',
#  '02537__529-郑堂放火炮除死无大灾',
#  '02157__138收服晏公',
#  '02269__251-草鞋公',
#  '02031__006人死蛇蜕壳',
#  '02073__051李侗智警张三府',
#  '02068__045出酒井',
#  '02558__550刘火索巧抗官府',
#  '02395__382烧纸钱的来历',
#  '02472__462王俊娶亲',
#  '02464__454蛤蟆精',
#  '02303__287海鸥',
#  '02155__136,窥井得天书',
#  '02361__348为什么初四过端午节',
#  '02579__572赵六滩打官司',
#  '02416__403藤缠枕',
#  '02522__514心平过得海',
#  '02266__248荒岛得宝',
#  '02105__087“林氏宗”',
#  '02593__586-附耳过来',
#  '02380__367为什么祭祀杀公鸡不杀鸭',
#  '02286__268海色为何爬到海滩生子',
#  '02108__090瓮仔周巧雕转头狮',
#  '02321__305黄旦茶',
#  '02391__378新婚桌“抢吃”的来历',
#  '02135__116严复见慈禧',
#  '02562__555郑德明教训牛贩子',
#  '02123__104板桥体',
#  '02572__565嘴会转',
#  '02093__071正德皇帝游花桥',
#  '02209__191＜宫井白龙洞',
#  '02431__419有孝感动天无孝遭雷打',
#  '02432__420#蛙状元',
#  '02254__236陈嘉庚择婿',
#  '02067__044受过“皇封的地皮好种食',
#  '02099__078锄头上天',
#  '02594__587不怕老婆的人',
#  '02104__086-黄汝良监斩魏忠贤',
#  '02294__277十二生肖排位',
#  '02248__230蛇王宫',
#  '02174__155孟姜女出世',
#  '02138__119不到黄河心不死',
#  '02236__218安平桥',
#  '02536__528相国千金吟蚊诗',
#  '02214__196神剑化龙',
#  '02482__473村妇戏考官',
#  '02033__009月儿为什么这么亮',
#  '02533__525假包公审真案',
#  '02366__353畲歌与祖牌',
#  '02163__144妈祖升天',
#  '02413__399青蛙赠珠',
#  '02456__445劝吊鬼',
#  '02292__275老鼠、猫、狗和五谷',
#  '02095__073戚家军吃“鼎边糊”',
#  '02261__243思乡曲',
#  '02216__198-#溪',
#  '02069__046南坑草鞋',
#  '02337__322香菇',
#  '02477__467聪明的三媳妇',
#  '02328__312龙眼和桂圆',
#  '02460__448墓生儿',
#  '02290__273黄瓜鱼给嘴害',
#  '02375__362诸娘人与唐部人',
#  '02275__257红蒜与白蒜',
#  '02257__239建造“华人池”',
#  '02467__457幌蚣庙',
#  '02062__039皇帝嘴乞丐身',
#  '02473__463靠自己建大厝',
#  '02497__488-考中状元又得妻',
#  '02576__569潘统除讼棍',
#  '02385__372哭嫁与伴娘',
#  '02433__421-+个兄弟',
#  '02476__466巧选当家人',
#  '02495__486“活城隍”惊死恶财佬',
#  '02427__415月亮上的砍树人',
#  '02369__356惠东妇女服饰的来历',
#  '02125__106黄慎画鸭',
#  '02509__500懒汉占卜',
#  '02528__520一帖灵',
#  '02196__177麒麟山',
#  '02352__338八宝印泥',
#  '02207__189-百丈崖',
#  '02233__215木兰陂',
#  '02259__241阿秀巧识奇信',
#  '02454__443谢公戏鬼',
#  '02565__558-＜惩匪徒',
#  '02140__121理发祖师吕洞宾',
#  '02047__024关公巧斩蔡阳',
#  '02101__082郑佑学琴',
#  '02350__336-脱胎漆器的传说',
#  '02171__152梁山伯与祝英台',
#  '02184__165沉东京浮福建',
#  '02379__366-擂茶的传说',
#  '02559__551状师钟九公',
#  '02169__150三宝建庙',
#  '02173__154祝英台的红裙变映山红',
#  '02224__206鲁班借龙宫',
#  '02247__229-甘露岩',
#  '02168__149乾隆拜妈祖',
#  '02317__301武夷山“大红袍',
#  '02484__475给皇帝画像',
#  '02592__585画虎成猫',
#  '02116__098蒲松龄戏财主',
#  '02086__064朱元璋三吟公鸡诗',
#  '02402__389猴虎相克',
#  '02481__472杀猴劝夫',
#  '02091__069马乐中状元',
#  '02055__032-韩偃巧遇草药仙',
#  '02043__020-#罗当宰相',
#  '02181__162白蛇法海前世孽',
#  '02549__541-正月初一闹公堂',
#  '02485__476传家“宝碗”',
#  '02229__211五福堂',
#  '02475__465公主与驸马',
#  '02330__314“宋家香',
#  '02362__349端午节挂菖蒲的来历',
#  '02087__065刘伯温选娘娘',
#  '02161__142铁马渡海',
#  '02210__192-十八银洞',
#  '02589__582买竹竿',
#  '02114__096-一范惊天',
#  '02305__289茉莉花',
#  '02192__173-九仙山',
#  '02409__395虎仔装新娘',
#  '02146__127-土地公与土地婆',
#  '02382__369念佛的由来',
#  '02545__537邱蒙请墓客',
#  '02245__227-凤山寺',
#  '02185__166武夷山名的来历',
#  '02462__452,狐狸仙做媒人',
#  '02112__094执法如山',
#  '02538__530穷家扮魁星富家谋子婿',
#  '02519__511慰姑娘岀嫁。',
#  '02164__145济度饥荒',
#  '02372__359-红顶帽，与长烟筒',
#  '02272__254-三保龙洞',
#  '02552__544计牵姻缘',
#  '02107__089瓮仔周得月华',
#  '02315__299石榴',
#  '02322__306-云雾茶',
#  '02316__300断肠草',
#  '02187__168天下第一山',
#  '02450__439-山石鬼',
#  '02249__231双龙抢珠',
#  '02118__099陈经邦作画治贪官',
#  '02524__516阿壮与村姑比武',
#  '02554__546刘火索送礼',
#  '02227__209报恩楼',
#  '02314__298日头王花',
#  '02179__160奏始皇筑长城',
#  '02182__163-牛郎织女会七夕',
#  '02142__123铁拐季和薯岭',
#  '02046__023关公智服周仓',
#  '02160__141妈祖书库',
#  '02357__343后九节的来历',
#  '02076__054朱熹与丽娘',
#  '02311__295含羞草',
#  '02282__264陈牯老脱险',
#  '02119__100闽戏神田元帅',
#  '02447__436测字先生',
#  '02051__028欧阳詹与荔枝姑娘',
#  '02130__111奴才脱鞋',
#  '02438__426有情和无义',
#  '02150__131跷腿的四大金刚',
#  '02585__578钟庄扮太子',
#  '02345__330-＜仔苗的传说',
#  '02469__459砧鞋驸马',
#  '02110__092郑成功凿水井',
#  '02510__501-1惰夫妻',
#  '02381__368闽中为何不见五帝庙',
#  '02162__143焚屋引航',
#  '02405__391鳖仔成亲',
#  '02508__499女婿借粮',
#  '02530__522医生和老板',
#  '02058__035南音祖师',
#  '02206__188-石锅盖',
#  '02547__539-W蒙买鸭蛋',
#  '02397__384,横锁船角的来历',
#  '02441__429-金瓜',
#  '02597__590抬你回去',
#  '02494__485-巧捅野蜂窝',
#  '02137__118画画嘲旅长',
#  '02097__076初四做“大岁”',
#  '02575__568惩无赖',
#  '04946__322老汉的宝物',
#  '04743__121造过麦山的白土城',
#  '05119__496伊斯玛悔过',
#  '05049__425三姊妹',
#  '04499__352灵童斗皇上',
#  '04524__377“鬼”闹油坊',
#  '08830__0734国王和傻子',
#  '09063__0971喜鹊和牛',
#  '08974__0880善有善报，恶有恶报',
#  '09061__0969小花猫养老鼠',
#  '08835__0740国王与瓜农',
#  '11148__432撒树叶',
#  '15360__083叉戛拉',
#  '15526__256蛇蜕皮人老死',
#  '15452__179-日本鬼子拉稀拉稀',
#  '15482__210孔明塘的传说',
#  '15478__206-香耙沟下美人函',
#  '13590__491娅扁和娅朗',
#  '01053__297-当归的传说',
#  '00911__154南宛河②和罗卜坝河',
#  '00863__105-蛇和人结姻缘',
#  '01016__260-玉龙雪山的传说',
#  '00967__211张三丰的土锅',
#  '04218__056冯玉祥剃头',
#  '04451__301铲路',
#  '01852__449满族是怎么来的',
#  '15483__211-禹门寺的木花门',
#  '15747__486-一家都是牛',
#  '15417__141』么佬哑巴王',
#  '15807__548忘性人',
#  '15436__163杨龙喜起义的传说',
#  '14044__271 .朶孙子',
#  '08965__0871猎手和他的朋友们',
#  '08778__0682A为财死，鸟为食亡',
#  '08821__0725国王和诙谐者',
#  '09087__0994鹰与孔雀',
#  '09012__0919玛纳坎的故事',
#  '12310__313雷公蛇和乌龟',
#  '12345__347逼女嫁蛇',
#  '05207__584丹德尔在阿拉善',
#  '05098__474怨不着媒人',
#  '05227__604阿古登巴缴税',
#  '13344__242大庸半边街的来历',
#  '13777__678钉后门',
#  '03500__875黄花菜的传说',
#  '07783__086平炯王和五象岭',
#  '08351__431两个儿子跟娘来',
#  '08055__224.侬秀姑娘给婆3弥梳头',
#  '07932__161芦笙七音调',
#  '08123__258老大和老二',
#  '14011__237.贵伊斯貂尔风俗的来历',
#  '01296__545仙人造桥',
#  '01191__435狐狸的报应',
#  '01081__324弹起本跳脚的由来',
#  '01436__686-姐夫与小姨妹',
#  '01263__511-蛇佳与彩秀',
#  '08857__0762审判',
#  '08698__0602人和鼠',
#  '08716__0620诚实的真肯巴图',
#  '09004__0910阿凡提的故事',
#  '08804__0708托娅',
#  '00803__045-青年射日',
#  '00825__067腊普和亚妞',
#  '00978__222怒族的迁居',
#  '00898__141搓日阿补征服女儿国',
#  '00799__041格悟松巴治太阳',
#  '04433__279-巧M妇',
#  '04560__414四件宝',
#  '14031__258.老虎和兔子',
#  '10429__237羊死后为啥不闭眼',
#  '04920__296善人与恶人',
#  '04733__111格德日沟山',
#  '04718__095曲库湖',
#  '08624__0526库木来克大力士',
#  '08484__0111三忠碑的传说',
#  '08553__0180布维玛丽亚姆墓',
#  '08467__0094秦公主的传说',
#  '08440__0067刘佛吾巧断鸡案',
#  '09100__1008耕牛与驴子',
#  '09117__1025吝啬鬼',
#  '08813__0717斯坎德尔国王和他的继承人',
#  '09110__1018我还以为是葫芦哩',
#  '08988__0894智谋老人',
#  '14078__305- #司乃比由',
#  '07928__159铜鼓镇母龙',
#  '08280__360卖鹅崽三打山主',
#  '08333__413b宽智取羊群',
#  '07982__186鸟做巢',
#  '07871__131.晒不死的竹叶草',
#  '01201__445老虎和山鼠',
#  '01105__349-玛丽妞和月半节',
#  '01084__327-芦笙和芦笙舞',
#  '01272__520门翁的故事',
#  '01110__354-泼水节与节令的由来',
#  '15575__306铜鼓节的由来',
#  '15523__251“不见哥哥只见斧凿',
#  '15841__583-祝笛梢和祝笛格',
#  '15765__504爱倩择婿',
#  '15740__479九重魔怪',
#  '07461__751.大话同年',
#  '05030__406大官和他的阿娜',
#  '04886__262吃人婆',
#  '04750__128库尔鲁克旗的地名',
#  '05292__讲述者；如胡牙安機拉族259农民和中',
#  '07748__069.三界公爷养菜牛',
#  '07958__174穿山甲中计',
#  '08229__313 .雅',
#  '07943__167.仙赐西山茶',
#  '07982__186鸟做巢',
#  '03535__910土地菩萨和农夫',
#  '00847__089红石和黑石的岩洞',
#  '00963__207阿端的传说',
#  '00951__195药神念黛娜',
#  '00888__131崇人抛鼎寻不死药',
#  '00766__008-祖先鱼上山',
#  '12507__033i家向王天子',
#  '04437__283女店主智难秀才',
#  '04444__292哈格子媳妇',
#  '13594__495红铜钱和绿铜钱',
#  '15480__208小黑龙显圣保草海',
#  '15768__507考媳妇',
#  '15299__020舜祖请太阳',
#  '15696__434果雅和梅依纳',
#  '15603__335“月也”的来历',
#  '02337__322香菇',
#  '13704__605寅喊卯到',
#  '13142__039裁衣的起源',
#  '15621__354土家猎人敬梅山',
#  '15668__404蜜蜂和喜鹊赌嘴',
#  '15620__353打铁心佬为啥祭老君',
#  '15509__237狗丢角',
#  '15829__571空坛子',
#  '15097__288-青蛙求亲',
#  '00789__031-地母三姑造万物',
#  '00884__126祭猎神',
#  '00844__086-石家什',
#  '00918__162柏洁夫人',
#  '00965__209张三丰写王皮也',
#  '04621__477牡呼',
#  '04440__288月夜明冤',
#  '04425__270-推磨',
#  '11317__015十个日头九个月',
#  '03333__702-昌格萨尔娶妻',
#  '07887__139.梅代朴',
#  '08110__252.玉仙姑娘',
#  '08119__256阿扎',
#  '07943__167.仙赐西山茶',
#  '08310__390牛归卜火',
#  '04692__069练臂石',
#  '04900__276宝葫芦与两兄弟',
#  '04840__216兔子报仇',
#  '04534__387-梦先生',
#  '04367__209拜克尔',
#  '14178__407- “舒坦”的故事',
#  '03561__938水牛和老虎',
#  '03211__1020鲁俄俄',
#  '15455__183-韭菜坪与女貌山',
#  '15327__050拆掉通天的桥',
#  '15311__032姜炎斗雷公',
#  '15591__322彭石二姓为啥不通婚',
#  '15336__059尹珍智对老学究',
#  '08246__326卖爸爸',
#  '07640__013.母子找天边',
#  '07768__079.三蝶奇缘',
#  '08041__217.包佐杀龙',
#  '08295__375奇长工奇联压财主',
#  '01418__668偏心灯',
#  '01096__339三月街的传说',
#  '01432__682-谁也晓不得',
#  '01086__329-巴板鸟与花统裙',
#  '01355__604贪心的弟弟',
#  '04844__220小兔子过关',
#  '05198__575肖格布尔加换枪',
#  '12295__299“打狗棍”',
#  '12691__218鸳鸯峰',
#  '12734__261±家神马',
#  '08914__0819马蹄子圆了来取钱',
#  '08702__0606骗子的下场',
#  '08743__0647西方问卦',
#  '08684__0586破石裱',
#  '08976__0882行凶作恶必遭惩处',
#  '08598__0500贤妇毛艳',
#  '08540__0167红庙子的来历',
#  '08631__0533馒巴图尔',
#  '08562__0189塔克拉玛干',
#  '08449__0076红脸勇士乌兰哈茨尔',
#  '02037__013-山羊与地震',
#  '04311__151红粉条',
#  '04596__452爱财如命',
#  '01131__375-露鲁人供祖的由来',
#  '01339__588-分不开的大树',
#  '01204__447小老鼠和马鹿',
#  '01343__592独儿子格茸',
#  '01068__311-三七的传说',
#  '00880__122木缸造火',
#  '01036__280-鱼化龙',
#  '00869__111尼施传彝文',
#  '01050__294芒果树为什么是弯的',
#  '00889__132起死回生药',
#  '02588__581线路来得紧',
#  '08995__0901选媳择婿',
#  '08910__0815努尔加玛丽公主',
#  '08728__0632伊尔朶姑娘',
#  '08947__0853骄傲的徒弟',
#  '08946__0852园丁老爷爷',
#  '10574__383胡蝎子租地',
#  '07369__659.老君公斩鲤鱼精',
#  '07862__126猫头鹰',
#  '08276__356干鱼庙',
#  '08218__307八女挑水',
#  '07881__136.乌柏树心不死',
#  '07847__118牯牛陡',
#  '03497__872猫和老鼠',
#  '03216__1025马为啥子不睡觉',
#  '14199__430.阿布都捉妖',
#  '07099__389.老鼠为什么夜间偷吃东西',
#  '08805__0709乌吐木喀莫尔根',
#  '08717__0621神羊的丿L子',
#  '08683__0585两位',
#  '09098__1006狐狸和罐子',
#  '08771__0675梧桐树',
#  '12118__120劳咏智灭野人',
#  '12322__324宝篮',
#  '10301__107刘墉巧解隐语',
#  '04984__360商人与魔鬼妻子',
#  '05210__587“敏干”云登和“一个”云登',
#  '05067__443达拉斗的故事',
#  '05086__462打官司',
#  '15550__280苗乡云雾茶',
#  '15473__201仙发桥的来由',
#  '15485__213-甲秀楼的传说',
#  '15335__058尹珍替学生还债',
#  '15506__234埋人田和烂沙坝',
#  '01052__296-半截观音',
#  '00832__074-从宗爷爷造人烟',
#  '00834__076-兄妹成婚',
#  '00900__143札努札别',
#  '00933__177抗法英雄项崇周',
#  '04449__299艾利伏和尔布都',
#  '04306__146杜尔盐的来历',
#  '04380__222黑娃和白鹰',
#  '04404__248-张宝除鬼',
#  '15805__546三个老汉比胡子',
#  '15375__098杨芳赞家乡',
#  '15535__265马桑泡为什么有毒',
#  '13589__490天梯',
#  '13523__423怕“屋漏',
#  '02402__389猴虎相克',
#  '04496__349活到老经不了',
#  '04384__226蛤蟆儿子',
#  '12811__338烧“毛狗棚',
#  '08877__0782聪明小伙娶公主',
#  '09033__0940够不着的葡萄是酸的',
#  '08942__0848功夫是苦练的结果',
#  '09074__0981当上大王的狐狸',
#  '08816__0720汗王和他的女婿',
#  '05281__658向导',
#  '04631__008四季的起源',
#  '05211__588等待第九百九十九个云登',
#  '01429__679-狗变国王国王变狗',
#  '01361__610仁义和财帛',
#  '01228__474魔穴救姑',
#  '01278__526-螺蜥菊',
#  '16092__262隐身衣',
#  '04432__278聪明的祖毕黛',
#  '15643__377咕咕咕唤鸡的缘由',
#  '15590__321“三天皇客当知府',
#  '15391__114石弹打官兵',
#  '15573__303爬山节的由',
#  '15717__455-两兄弟和两姊妹',
#  '07353__643.唐十二八公斗魔鬼',
#  '12443__445-打灰与螺比赛',
#  '12113__115黎王保黑马当',
#  '05020__396齐心的六兄弟',
#  '04737__115北山林地的来历',
#  '04855__231飞禽可汗和乌鸦',
#  '04960__336报恩',
#  '05052__428学针线',
#  '04666__043罗卜藏丹津的下落',
#  '05215__592教训小喇嘛',
#  '07963__177 .杀猪吃肉',
#  '08332__412卜宽过年',
#  '07905__148 .砍牛祭葬',
#  '07907__149.蛙婆节',
#  '07831__110花龙与风雨桥',
#  '13118__015盘瓠',
#  '03524__899巧三妹',
#  '14104__331.金角银蹄牛犊',
#  '13829__051.吴玲破铁骑',
#  '14132__360.新媳妇驱鬼',
#  '07990__190海龙王开大会',
#  '07677__031忠勇公苏缄',
#  '08083__238茶花姑＞',
#  '08343__423李海进临死报仇',
#  '09064__0972小财主想发大财',
#  '09009__0915吉林谢的故事',
#  '08983__0889阿斯玛巧治恶老太婆',
#  '08801__0705公鸡精',
#  '03215__1024蒙古族为什么没有经书',
#  '12270__274俄娘洞与黎族三月三',
#  '12303__306狗与黄源',
#  '12362__364银仙',
#  '08752__0656骑神驹的坎德拜勇士',
#  '09097__1005狐狸和虾',
#  '08875__0780神奇的苹果',
#  '08796__0700新可汗继位',
#  '08799__0703猫精',
#  '08520__0147猩猩峡与星星峡',
#  '08470__0097夏尼什胡勒',
#  '08488__0115博格达山的传说',
#  '08609__0511勇敢的吾热力和狡诈的国王',
#  '08485__0112库尔察克的传说',
#  '01054__298葱和大蒜的来历',
#  '00783__025-布洛陀',
#  '00822__064-洪水后幸存的两兄妹',
#  '00950__194刮摩毕打铁除妖',
#  '02560__553-寡妇改嫁',
#  '15420__145广大公子',
#  '15430__156蛮王洞',
#  '15460__188耗子岩',
#  '15630__363祭米魂的由来',
#  '15822__563哥义摘杨梅',
#  '13494__394虎牛斗智',
#  '13705__606±辣子粪',
#  '13746__647百合花',
#  '08001__196蚂蚁和蚯蚓',
#  '07816__103.西山乳泉',
#  '08300__380—把屠刀',
#  '08218__307八女挑水',
#  '08369__449还有一件事对不起你',
#  '04671__048齐力毕摔跤',
#  '05226__603阿古登巴救仆人',
#  '04895__271兄弟分家',
#  '15434__161马云根领导打土司',
#  '15281__001天和地是咋个来的',
#  '15843__585懒惰的小鸡',
#  '15680__416札西',
#  '15374__097赵世万接帖赴宴',
#  '01114__358-花街节',
#  '01371__620-千金与万两',
#  '01421__671-W搭豹子做生意',
#  '01161__405阿注婚的来由',
#  '01232__478-罗多斯白的故事',
#  '10314__120李莲英左右收贿',
#  '08345__425计叔娶妻',
#  '07725__055郎帕',
#  '07844__117.飞来石和三将军',
#  '08024__207猫狗寻宝',
#  '08104__249.两世姻缘',
#  '12602__129陈连升和他的黄验马',
#  '08450__0077嘎勒丹巴的传说',
#  '08575__0477孤儿和仙女',
#  '08592__0494伯孜依格特',
#  '08551__0178帕尔哈德渠的传说',
#  '08626__0528狮子大力士',
#  '08722__0626金鞋',
#  '08950__0856机灵的巴尔马克西',
#  '08847__0752机灵的小伙子',
#  '08841__0746宛朶斯巧斗坏财主',
#  '08768__0672大萝卜、水萝卜、青钗果',
#  '12372__374翠鸟衣换皇袍',
#  '12438__440-孟征巧弄财主',
#  '12280__284苗寨祀奉土地公',
#  '04479__329瓜女婿打蜿蚤',
#  '15988__149三放人花',
#  '01212__455山鸡后悔了',
#  '01223__468马鹿儿子',
#  '01142__386祭树神',
#  '01280__528-神奇的果树',
#  '01165__409-穿黑衣黑裤的传说',
#  '13317__215吴天求起事跳仙',
#  '13461__360跳香节的来历',
#  '13571__471纣纣和老虎交朋友',
#  '15484__212-娘娘庙的传说',
#  '15844__586-大树和藤藤',
#  '15637__371脑门上插木梳',
#  '15773__513少灵斗土司',
#  '15628__361沆溼的传说',
#  '01347__596见死不救的下场',
#  '01209__452山霸王的下场',
#  '01227__473孤儿与龙姑娘',
#  '01305__554-老猎手智灭“特缺',
#  '01077__320八宝米的传说',
#  '14382__160奏始皇筑长城',
#  '15638__372人为什么背着手走路',
#  '15790__531摸锄把',
#  '15779__519汉王和祖王',
#  '15595__326吃牯脏的来历',
#  '15563__293玉屏洞箫传仙韵',
#  '01168__412拉祜族妇女不系腰带',
#  '01330__579-两亲家',
#  '01083__326葫芦笙的传说',
#  '01292__541-金雀',
#  '01320__569-格桑洛顶和东鲁祝玛',
#  '14950__141杀鸡占卜的由来',
#  '00906__149神奇的女山神',
#  '01059__303红脖子绿牙蛇',
#  '08119__256阿扎',
#  '01047__291-树和草为什么这样多',
#  '00902__145丁巴什罗',
#  '05019__395两兄弟学魔法的故事',
#  '04677__054朱海山的传说',
#  '04744__122单阳城',
#  '04361__201红葫芦',
#  '07980__185鸭子孵蛋',
#  '07722__054.歌师吴朝堂',
#  '08079__236山鹰姑娘',
#  '07696__041.卢天送射敌',
#  '08110__252.玉仙姑娘',
#  '07036__325.皇后井',
#  '03487__862-张胡子抢照片',
#  '03366__736乌鸦国王',
#  '13550__450蝴蝶姑娘',
#  '13748__6491匠织背篓',
#  '13453__352瑶家端午挂葛藤',
#  '07772__081.千家崛的传说',
#  '08215__306.灶王十二兄弟',
#  '07898__144不为篼龄人做寿的由来',
#  '05087__463先生和后生',
#  '04854__230鸟王、喜鹊和乌鸦',
#  ...]

# %%
df_filtered = df[~df['文件名称'].isin(combined_list)]
df_filtered.shape[0]
# Out:
# 12957

# %%
df_filtered.head()
# Out:
#                    文件名称                                               文本内容  \
# 2    15626__359祭煤窑神节的由来  359.祭煤窑神节的由来\n\nFa\n\n（汉族?盘县特区）\n\n在很多年以前，正月十七...
# 6       15647__381水牛和老虎  381 .水牛和老虎\n\n（壮族?荔波县）\n\n从前有一天，水牛在山坡上吃草，有一只老虎...
# 12       15283__003开天辟地  003.开天辟地\n\n（侗族?三穗县）\n\n天地原来是一大团滚烫的脓脓水水，后来慢慢地变...
# 19      15746__485碰巧成妙对  485.碰巧成妙对\n\n\n\n\n\n\n\n\n\n\n\n从前，有一个财主姓程，家中...
# 139      15796__537两人争官  537.两人争官\n\n（布依方矣?罗句县）\n\n从前，马伍和陈朋两人，一同上京会试，都中...
#
#      畜牧业  棉花  小麦  渔业
# 2      1   0   0   0
# 6      1   0   0   0
# 12     0   0   0   0
# 19     0   0   1   0
# 139    0   0   0   0

# %%
file_path = "/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/data/raw_data_tales/地图匹配_0426_v4.csv"
df = pd.read_csv(file_path)
merged_df = pd.merge(df, df_filtered, left_on="name", right_on="文件名称", how="left")
merged_df = merged_df.dropna(subset=["文件名称"])
merged_df.head()
# Out:
#    rowid                name                            cailu  \
# 4      5     04849__225老鼠的智慧                   missing values
# 5      6  06997__285.大人山和弯角顶                  黄益新 1987年采录于信宜县
# 6      7   07006__294.丹霞山出米洞           黄海燕 1987年8月采录于花县新华镇乐同乡
# 7      8    07168__460.龙门胡须鸡  罗振球男38岁龙门县文化馆干部大专 1986年5月采录于龙门县
# 8      9   07474__764.李起初讨批文                   missing values
#
#             provgb           citygb           cntygb     area  \
# 4  missing valuesd  missing valuesd  missing valuesd  宁夏藏抜同仁县
# 5               44             4410           440983    广东信宜县
# 6               44             4402           440224    广东仁化县
# 7               44             4413           441324    广东龙门县
# 8               44             4453           445300    广东云浮县
#
#                                  geocode  PROVGB_1953  CITYGB_1953  ...  \
# 4  {'lng': 116.413384, 'lat': 39.910925}          NaN          NaN  ...
# 5  {'lng': 110.953582, 'lat': 22.360093}         44.0       4463.0  ...
# 6  {'lng': 113.748627, 'lat': 25.088226}         44.0       4461.0  ...
# 7  {'lng': 114.259986, 'lat': 23.723894}         44.0       4460.0  ...
# 8  {'lng': 116.413384, 'lat': 39.910925}         44.0       4460.0  ...
#
#    CITYGB_2010  CNTYGB_2010  new_name  area_group                文件名称  \
# 4          NaN          NaN     老鼠的智慧          宁夏     04849__225老鼠的智慧
# 5          NaN          NaN   大人山和弯角顶          广东  06997__285.大人山和弯角顶
# 6          NaN          NaN    丹霞山出米洞          广东   07006__294.丹霞山出米洞
# 7          NaN          NaN     龙门胡须鸡          广东    07168__460.龙门胡须鸡
# 8          NaN          NaN    李起初讨批文          广东   07474__764.李起初讨批文
#
#                                                 文本内容  畜牧业   棉花   小麦   渔业
# 4  225.老鼠的智慧\n\n（藏抜同仁县）\n\n有一次.老鼠、青蛙、狼，为争夺一件宝物争吵不...  1.0  0.0  0.0  0.0
# 5  285.大人山和弯角顶\n\n（信宜县）\n\n相传很久很久以前，黎村和金洞是个天湖。湖中鱼...  1.0  0.0  0.0  1.0
# 6  294.丹霞山出米洞\n\n（仁化县）\n\n丹霞山的锦石岩，有一个大雄宝殿，殿旁有一岩壁叫...  0.0  0.0  0.0  0.0
# 7  460.龙门胡须鸡\n\n（龙门县）\n\n相传.在四百多年前，龙门县的一个小山村，有一个美...  1.0  0.0  0.0  0.0
# 8  764.李起初讨批文\n\n（云浮县）\n\n从前，都骑乡山口村有个文人，他写了一篇文章，到...  0.0  0.0  0.0  0.0
#
# [5 rows x 34 columns]

# %%
columns = ['畜牧业', '棉花', '小麦', '渔业']

# 按 'area_group' 列分组，计算相似度列的平均值
grouped_df = merged_df.groupby('area_group')[columns].mean()
grouped_df
# Out:
#                  畜牧业        棉花        小麦        渔业
# area_group
# 上海          0.167546  0.040897  0.076517  0.205805
# 云南          0.350000  0.000000  0.200000  0.150000
# 北京          0.197898  0.015762  0.113835  0.077058
# 四川          0.350437  0.019651  0.113537  0.117904
# 天津          0.195933  0.033272  0.118299  0.253235
# 宁夏          0.416523  0.018933  0.166954  0.044750
# 安徽          0.225610  0.039024  0.121951  0.158537
# 山西          0.263514  0.032095  0.135135  0.067568
# 广东          0.225352  0.023474  0.098592  0.203052
# 广西          0.409231  0.049231  0.209231  0.292308
# 新疆          0.529412  0.000000  0.235294  0.000000
# 江苏          0.169231  0.020513  0.073504  0.174359
# 江西          0.215886  0.026477  0.109980  0.158859
# 河北          0.201566  0.048924  0.127202  0.107632
# 河南          0.215971  0.019964  0.154265  0.083485
# 浙江          0.190547  0.014771  0.091581  0.169867
# 海南          0.222591  0.016611  0.056478  0.179402
# 湖北          0.188811  0.026224  0.080420  0.111888
# 湖南          0.214008  0.017510  0.101167  0.165370
# 甘肃          0.439528  0.014749  0.191740  0.053097
# 福建          0.234347  0.025045  0.101968  0.202147
# 西藏          0.636145  0.002410  0.130120  0.081928
# 贵州          0.478261  0.043478  0.130435  0.217391
# 辽宁          0.240418  0.031359  0.125436  0.198606
# 陕西          0.221509  0.024077  0.138042  0.069021

# %%
import pandas as pd

# 假设你的 DataFrame 名为 df
# 定义一个映射字典
province_mapping = {
    "上海": "上海市",
    "云南": "云南省",
    "北京": "北京市",
    "吉林": "吉林省",
    "四川": "四川省",
    "天津": "天津市",
    "宁夏": "宁夏回族自治区",
    "安徽": "安徽省",
    "山西": "山西省",
    "广东": "广东省",
    "广西": "广西壮族自治区",
    "新疆": "新疆维吾尔自治区",
    "江苏": "江苏省",
    "江西": "江西省",
    "河北": "河北省",
    "河南": "河南省",
    "浙江": "浙江省",
    "海南": "海南省",
    "湖北": "湖北省",
    "湖南": "湖南省",
    "甘肃": "甘肃省",
    "福建": "福建省",
    "西藏": "西藏自治区",
    "贵州": "贵州省",
    "辽宁": "辽宁省",
    "陕西": "陕西省"
}

# 使用映射字典更新索引
grouped_df.index = grouped_df.index.map(province_mapping)

grouped_df
# Out:
#                  畜牧业        棉花        小麦        渔业
# area_group
# 上海市         0.167546  0.040897  0.076517  0.205805
# 云南省         0.350000  0.000000  0.200000  0.150000
# 北京市         0.197898  0.015762  0.113835  0.077058
# 四川省         0.350437  0.019651  0.113537  0.117904
# 天津市         0.195933  0.033272  0.118299  0.253235
# 宁夏回族自治区     0.416523  0.018933  0.166954  0.044750
# 安徽省         0.225610  0.039024  0.121951  0.158537
# 山西省         0.263514  0.032095  0.135135  0.067568
# 广东省         0.225352  0.023474  0.098592  0.203052
# 广西壮族自治区     0.409231  0.049231  0.209231  0.292308
# 新疆维吾尔自治区    0.529412  0.000000  0.235294  0.000000
# 江苏省         0.169231  0.020513  0.073504  0.174359
# 江西省         0.215886  0.026477  0.109980  0.158859
# 河北省         0.201566  0.048924  0.127202  0.107632
# 河南省         0.215971  0.019964  0.154265  0.083485
# 浙江省         0.190547  0.014771  0.091581  0.169867
# 海南省         0.222591  0.016611  0.056478  0.179402
# 湖北省         0.188811  0.026224  0.080420  0.111888
# 湖南省         0.214008  0.017510  0.101167  0.165370
# 甘肃省         0.439528  0.014749  0.191740  0.053097
# 福建省         0.234347  0.025045  0.101968  0.202147
# 西藏自治区       0.636145  0.002410  0.130120  0.081928
# 贵州省         0.478261  0.043478  0.130435  0.217391
# 辽宁省         0.240418  0.031359  0.125436  0.198606
# 陕西省         0.221509  0.024077  0.138042  0.069021

# %%
import os
from pyecharts.charts import Map
from pyecharts import options as opts

# 生成地图的函数
def generate_map(dataframe, column_name, output_folder):
    """
    根据给定的列生成一张地图并保存到指定文件夹。
    :param dataframe: 数据表
    :param column_name: 需要绘制的列名
    :param output_folder: 保存 HTML 文件的文件夹路径
    """
    # 确保输出文件夹存在
    os.makedirs(output_folder, exist_ok=True)

    # 数据准备
    data = list(zip(dataframe.index, dataframe[column_name]))  # 将地区和数值打包成列表
    
    # 创建地图
    map_chart = (
        Map()
        .add(
            series_name=column_name,  # 显示的图例名称
            data_pair=data,  # 地区与数据对
            maptype="china",  # 地图类型：中国
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=f"{column_name} 地图"),
            visualmap_opts=opts.VisualMapOpts(
                max_=dataframe[column_name].max(),
                min_=dataframe[column_name].min(),
            range_color=[
                "#f7fbff", "#e6f4fc", "#d2e9f7", "#c2e0f7", "#a3c9f2", 
                "#85b2ed", "#669ce8", "#4a88e3", "#3f75a5", "#2c5b88", 
                "#234c72", "#1c3b5d"
            ]
           ),
        )
    )
    
    # 保存为 HTML 文件，并设置宽高
    output_path_html = os.path.join(output_folder, f"{column_name}_map.html")
    map_chart.render(output_path_html, width="1200px", height="800px")  # 通过 render 设置宽高
    print(f"{column_name} 的地图已生成并保存到 {output_path_html}！")

# 指定输出文件夹
output_folder_html = "/Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123map_validation_questions"

# 遍历 grouped_df 的每一列生成地图
for column in grouped_df.columns:
    generate_map(grouped_df, column, output_folder_html)
# Out:
# 畜牧业 的地图已生成并保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123map_validation_questions/畜牧业_map.html！
# 棉花 的地图已生成并保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123map_validation_questions/棉花_map.html！
# 小麦 的地图已生成并保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123map_validation_questions/小麦_map.html！
# 渔业 的地图已生成并保存到 /Users/zhaorunping/Desktop/Research_Onging/2410_LSE_Xue/result/241123map_validation_questions/渔业_map.html！

# %%
pip install snapshot-selenium
# Out:
# Collecting snapshot-selenium
#   Downloading snapshot_selenium-0.0.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting selenium (from snapshot-selenium)
#   Downloading selenium-4.26.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium->snapshot-selenium) (1.26.20)
# Collecting trio~=0.17 (from selenium->snapshot-selenium)
#   Downloading trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium->snapshot-selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from selenium->snapshot-selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from selenium->snapshot-selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from selenium->snapshot-selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium->snapshot-selenium)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sortedcontainers in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium->snapshot-selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium->snapshot-selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium->snapshot-selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium->snapshot-selenium) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->snapshot-selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium->snapshot-selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/Anaconda/anaconda3/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->snapshot-selenium) (0.14.0)
# Downloading snapshot_selenium-0.0.2-py2.py3-none-any.whl (3.0 kB)
# Downloading selenium-4.26.1-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 8.4 MB/s eta 0:00:00a 0:00:01
# Downloading trio-0.27.0-py3-none-any.whl (481 kB)
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium, snapshot-selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-24.2.0 outcome-1.3.0.post0 selenium-4.26.1 snapshot-selenium-0.0.2 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
